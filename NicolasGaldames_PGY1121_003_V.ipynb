# %%
import numpy as np

# %%
ubicaciones = []

# %%
def comprar_entradas():

  while True:

    print('')
    print('PRECIOS DE ENTRADAS')
    print('')
    print('1.- Platinum, $120.000. (Asientos del 1 al 20)')
    print('2.- Gold, $80.000. (Asientos del 21 al 50)')
    print('3.- Silver, $50.000. (Asientos del 51 al 100)')
    print('')

    cantidad_entradas = int(input('Ingrese cantidad de entradas a comprar: '))
    if cantidad_entradas > 0 and cantidad_entradas < 4:
      print("UBICACIONES DISPONIBLES")
      for i in range(10):
        for j in range(10):
          if ubicaciones[i][j] == 0:
            print(f"{i * 10 + j + 1:<3}", end="")
          else:
            print("X  ", end="")
          print()

        asiento = int(input('Por favor, ingrese el número de asiento que desea: '))
        if asiento > 0 and asiento < 101:
          rut = int(input('Ingrese rut de la persona(SIN PUNTOS NI DÍGITO VERIFICADOR): '))
          if len(str(rut)) == 8:
            print('Compra exitosa')
          else:
            print('el rut debe ser ingresado SIN PUNTOS NI DÍGITO VERIFICADOR')
        else:
          print('Asiento inexistente')

# %%
def ubicaciones_disponibles():
  print("UBICACIONES DISPONIBLES")
  for i in range(10):
    for j in range(10):
      if ubicaciones[i][j] == 0:
        print(f"{i * 10 + j + 1:<3}", end="")
      else:
        print("X  ", end="")
    print()

# %%
def listado_asistentes():

  print('LISTADO DE ASISTENTES')
  print('')
  print('Rut:')
  print('Asiento:')
  print('')

# %%
def ganancias_totales():
  print('')
  print('Tipo asiento: ')
  print('Total: ')
  print('')

# %%
def salir():

  print(36*'*')
  print('*         ¡Hasta pronto!           *')
  print('* Creador del SW: Nicolas Galdames *')
  print('*        Fecha: 11/07/2023         *')
  print(36*'*')
  return 0

# %%
def menu():

  while True:
    print('---- Bienvenido a "Creativos.cl" ----')
    print('')
    print('Menú de opciones:')
    print('')
    print('1.- Comprar entradas')
    print('2.- Ubicaciones disponibles')
    print('3.- Listado de asistentes')
    print('4.- Ganancias totales')
    print('5.- Salir')

    try:
      print('')
      opcion = int(input('Por favor, seleccione una opción del menú: '))
      print('')

      if opcion == 1:
        comprar_entradas()
      elif opcion == 2:
        ubicaciones_disponibles()
      elif opcion == 3:
        listado_asistentes()
      elif opcion == 4:
        ganancias_totales
      elif opcion == 5:
        salir()
        break
      else:
        print('Opción inválida. Por favor seleccione una de las opciones del menú.')
        print('')
    except:
      print('')
      print('Opción inválida. Por favor seleccione una de las opciones del menú.')
      print('')

# %%
menu()
